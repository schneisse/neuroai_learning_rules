# %%
import data_handling as dh

# %%
train_set, valid_set, test_set = dh.download_mnist()
# Out:
# Number of examples retained:
#   24001 (training)
#   5999 (validation)
#   5000 (test)

# %%
# @title Importing dependencies

from IPython.display import Image, SVG, display
import os
from pathlib import Path

import random
from tqdm import tqdm
import warnings
import numpy as np
import matplotlib.pyplot as plt
import scipy
import torch
import torchvision
import contextlib
import io

# %%
dh.plot_examples(train_set)
# Out:
# <Axes: title={'center': 'Examples per class'}, xlabel='Class'>

# %% [markdown]
# https://discuss.pytorch.org/t/parallelize-architecture-for-predictive-coding-architecture/138581
